# %% [markdown]
# # Clustering using K-means
#
# ### https://realpython.com/k-means-clustering-python/
# ### https://github.com/benjaminwilson/python-clustering-exercises

# %% [markdown]
# ## Read the dataset and vizualize its content

# %%
import pandas as pd

df = pd.read_csv('datasets/clusters.csv')

df.head()
# Out:
#           0         1
# 0  0.065446 -0.768664
# 1 -1.529015 -0.429531
# 2  1.709934  0.698853
# 3  1.167791  1.012626
# 4 -1.801101 -0.318613

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

# %% [markdown]
# #### Prepare the X & Y values

# %%
points_x = df['0']
points_y = df['1']

# %%
plt.scatter(points_x, points_y)

# %% [markdown]
# ### Read a dataset closer to a real-world behaviour

# %%
df = pd.read_csv('datasets/seeds.csv')

df.head()
# Out:
#     area  perimeter  compactness  length  width  asymmetry_coefficient  \
# 0  15.26      14.84       0.8710   5.763  3.312                  2.221
# 1  14.88      14.57       0.8811   5.554  3.333                  1.018
# 2  14.29      14.09       0.9050   5.291  3.337                  2.699
# 3  13.84      13.94       0.8955   5.324  3.379                  2.259
# 4  16.14      14.99       0.9034   5.658  3.562                  1.355
#
#    groove_length grain_variety
# 0          5.220    Kama wheat
# 1          4.956    Kama wheat
# 2          4.825    Kama wheat
# 3          4.805    Kama wheat
# 4          5.175    Kama wheat

# %% [markdown]
# ### Let's vizualize if the clusters are similary well defined as in the first case

# %%
length = df.length
width = df.width

plt.scatter(length, width)
